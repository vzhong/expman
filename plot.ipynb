# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from expman import Experiment, JSONLogger
from expman.plotters import LinePlotter
from matplotlib import pylab as plt

data = Experiment.discover_logs(glob_path='logs/seeded/*', logger=JSONLogger())

# %%
plotter = LinePlotter()
fig, ax = plt.subplots(figsize=(5, 5))
plotter.plot(data, x='step', y='acc', group='type', xpid='project', read_every=2, smooth_window=2, ax=ax)
# Out:
# /Users/victor/anaconda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/victor/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/victor/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# ...
